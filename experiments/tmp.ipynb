# %%
from transformers import pipeline
sentiment_pipe = pipeline(
    "sentiment-analysis", 
    model="/home/xinglixian/models/twitter-roberta-base-sentiment-latest", 
    device='cuda',
    top_k=1
)
# Out:
# Some weights of the model checkpoint at /home/xinglixian/models/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cuda

# %%
prompts = [
    'this movie is',
    'I love this',
    'I hate this'
]
print(sentiment_pipe(prompts))
# Out:
# [[{'label': 'neutral', 'score': 0.6384227275848389}], [{'label': 'positive', 'score': 0.950330376625061}], [{'label': 'negative', 'score': 0.8117084503173828}]]

# %%
prompts = [
    'this movie is',
    'I love this',
    'I hate this'
]
print(sentiment_pipe(prompts))
# Out:
# [[{'label': 'POSITIVE', 'score': 0.703900158405304}, {'label': 'NEGATIVE', 'score': 0.29609978199005127}], [{'label': 'POSITIVE', 'score': 0.9943503737449646}, {'label': 'NEGATIVE', 'score': 0.005649638827890158}], [{'label': 'NEGATIVE', 'score': 0.9620260000228882}, {'label': 'POSITIVE', 'score': 0.03797394409775734}]]

# %%
import pandas as pd

df = pd.read_parquet('/home/xinglixian/data/imdb_ppo_prefix_balanced/test.parquet')

df.head()
# Out:
#         data_source                                             prompt  \
# 0  stanfordnlp/imdb  [{'content': 'Continue the following movie rev...
# 1  stanfordnlp/imdb  [{'content': 'Continue the following movie rev...
# 2  stanfordnlp/imdb  [{'content': 'Continue the following movie rev...
# 3  stanfordnlp/imdb  [{'content': 'Continue the following movie rev...
# 4  stanfordnlp/imdb  [{'content': 'Continue the following movie rev...
#
#             ability                           reward_model  \
# 0  creative_writing  {'ground_truth': 0, 'style': 'model'}
# 1  creative_writing  {'ground_truth': 1, 'style': 'model'}
# 2  creative_writing  {'ground_truth': 1, 'style': 'model'}
# 3  creative_writing  {'ground_truth': 0, 'style': 'model'}
# 4  creative_writing  {'ground_truth': 1, 'style': 'model'}
#
#                                           extra_info
# 0  {'index': 3, 'original_label': 0, 'original_te...
# 1  {'index': 7, 'original_label': 1, 'original_te...
# ...

# %%
from collections import defaultdict
import json
from datasets import Dataset
cnt = defaultdict(int)
data = Dataset.from_pandas(df)
print(data)
# Out:
# Dataset({
#     features: ['data_source', 'prompt', 'ability', 'reward_model', 'extra_info'],
#     num_rows: 300
# })

# %%
for line in data:
    cnt[line['extra_info']['prefix_sentiment_label']] += 1
    
cnt
# Out:
# defaultdict(int, {0: 100, 1: 100, 2: 100})
